# %%
# Print Function

print('Hello world')
# Out:
# Hello world

# %%
# User-input function

input("Enter your city here :- ")
# Out:
# Enter your city here :- NYC
# 'NYC'

# %%
# Variables

name = "This is a tree ." # sentence

# %%
print(name)
# Out:
# This is a tree .

# %%
# Boolean

# 2+2>=3+1 # >= stands for greater than or equals to
2==3
# Out:
# False

# %%
# integers

num1 = int(input("Enter the first number here :- ")) # 1 = "1" = 1
num2 = int(input("Enter the second number here :- "))# 2 = "2" = 2

sum = num1 + num2 # "2"+"1" = 21 ; 1+2 = 3
print(sum)
# Out:
# Enter the first number here :- 1
# Enter the second number here :- 2
# 3

# %%
# Float are decimal numbers

num1 = float(input("Enter the first number here :- "))
num2 = float(input("Enter the second number here :- "))

sum = num1+num2
print(sum)
# Out:
# Enter the first number here :- 2
# Enter the second number here :- 3
# 5.0

# %%
listshopping = ['tomato', 'potato', 'noodles', 'green onions']
#                   0         1          2            3
print(listshopping)
# Out:
# ['tomato', 'potato', 'noodles', 'green onions']

# %%
listshopping[0]
# Out:
# 'tomato'

# %%
listshopping[3]
# Out:
# 'green onions'

# %%
listshopping[:3]
# Out:
# ['tomato', 'potato', 'noodles']
